# %% [markdown]
# ***GENERATED CODE FOR dataprepdateconv PIPELINE.***

# %% [markdown]
# ***DON'T EDIT THIS CODE.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO READ DATA.***

# %%
import os
import datetime
import logging
import warnings
warnings.filterwarnings('ignore')
logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.INFO)


class HDFSConnector:

    def fetch(spark, config):
        ################### INPUT HADOOP HOST PORT TO CONNECT WITH ###############################
        hdfs_server = str(os.environ['HDFS_SERVER'])
        hdfs_port = int(os.environ['HDFS_PORT'])
        df = spark.read.options(header='true', inferschema='true').csv(
            f"hdfs://{hdfs_server}:{hdfs_port}{eval(config)['url']}", header='true')
        display(df.limit(2).toPandas())
        return df

    def put(df, spark, config):
        return df.write.format('csv').options(header='true' if eval(config)["is_header"] == "Use Header Line" else 'false',
                                              delimiter=eval(config)["delimiter"]).save(("%s %s") % (datetime.datetime.now().strftime("%Y-%m-%d %H.%M.%S")+"_", eval(config)['url']))

# %% [markdown]
# ***OPERATION FUNCTIONS***

# %%
import pyspark
from dask.dataframe import from_pandas
import json


def DateTransform(df, functionsData, applyOn=[]):
    import dask.dataframe as dd
    import pandas as pd
    import numpy as np

    for functiondata in functionsData:
        functiondata = functiondata

    dfcp = df
    dfcp1 = dfcp
    resulttype = dfcp1.select_dtypes(include=[np.datetime64])
    for existingdatecols in resulttype.columns:
        dfcp[existingdatecols] = dfcp[existingdatecols].apply(
            lambda x: x.replace(tzinfo=None))

    Dateformat1 = 'YYYY-DD-MM'
    Dateformat2 = 'YY/MM/DD'
    Dateformat3 = 'DD/MM/YYYY'
    Dateformat4 = 'M/D/YY'
    NotDateFromat = [Dateformat1, Dateformat2, Dateformat3, Dateformat4]

    if 'inputDateFormat' in functiondata:
        coldetail = functiondata['column']
        for col in coldetail:
            colname = col['columnName']
        inputFormat = str(functiondata['inputDateFormat'])
        functiondata['outputDateFormat']
        functiondata['newColumn']
    if ('newColumnName' in functiondata):
        if inputFormat in NotDateFromat:
            NewDateCol = functiondata['newColumnName']
            dfcp = dfcp.compute()
            dfcp[NewDateCol] = dfcp[colname].apply(
                lambda x: pd.to_datetime(x, format='%d/%m/%Y', utc=False))
            dfcp[NewDateCol] = dfcp[NewDateCol].apply(
                lambda x: x.strftime("%Y-%m-%d"))
            dfcp[NewDateCol] = pd.to_datetime(dfcp[NewDateCol], utc=False)
            dfcp = dd.from_pandas(dfcp, npartitions=2)
            dfcp[NewDateCol] = dfcp[NewDateCol].apply(
                lambda x: x.replace(tzinfo=None))
    elif (('newColumnName' not in functiondata) and (inputFormat in NotDateFromat)):
        dfcp = dfcp.compute()
        dfcp[colname] = dfcp[colname].apply(
            lambda x: pd.to_datetime(x, format='%d/%m/%Y'))
        dfcp[colname] = dfcp[colname].apply(lambda x: x.strftime("%Y-%m-%d"))
        dfcp[colname] = pd.to_datetime(dfcp[colname], utc=False)
        dfcp = dd.from_pandas(dfcp, npartitions=2)

    return dfcp


def SortData(df, functionsData, applyOn=[]):
    for functiondata in functionsData:
        coldetail = functiondata['column']
        sortdetails = functiondata['order']
        for col in coldetail:
            colname = col['columnName']
    if sortdetails == "asc":
        SortReq = True
    else:
        SortReq = False

    df = df.set_index(colname)
    #df = df.sort_values(by = colname, ascending=SortReq)

    df = df.map_partitions(lambda df: df.sort_values(
        [colname], ascending=SortReq)).reset_index()

    return df


def runDataCleansing(sparkDf, spark, config):
    configObj = json.loads(config)
    sparkDf.persist(pyspark.StorageLevel.MEMORY_AND_DISK)
    df = from_pandas((sparkDf.toPandas()), npartitions=5)
    functionList = configObj['functionsApplied']
    Data_Cleansing_Methods = {"replaceBy": replaceValues,
                              "formula": calculateFormula,
                              "aggregate": aggregation,
                              "converttostringtype": changeToString,
                              "editname": renameColumns}
    for function in functionList:
        function['functionName']
        df = Data_Cleansing_Methods[function['functionName']](df, function['functionsData'],
                                                              function['applyOn'])
    sparkDf = spark.createDataFrame(df.compute())

    display(sparkDf.limit(2).toPandas())
    return sparkDf

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO WRITE DATA.***

# %%
import datetime
import requests
import datetime
import logging
import warnings
warnings.filterwarnings('ignore')
logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.INFO)


class NumtraConnector:

    def put(inStages, inStagesData, stageId, spark, config):
        path = eval(config)['server_url']
        baseType = eval(config)['baseType']
        results_url = eval(config)['results_url']
        server = eval(config)['server']
        originalfile = eval(config)['orignalKey']
        eval(config)['pathOnly']
        filename = eval(config)['filename']
        eval(config)['ser']
        eval(config)['user']
        eval(config)['password']
        eval(config)['authSource']
        eval(config)['user_id']
        eval(config)['parent_id']
        eval(config)['project_id']
        time = str(int(datetime.datetime.now().timestamp()))

        inStagesData[inStages[0]]

        print(path)
        print(baseType)
        print(results_url)
        print(server)
        print(originalfile)
        print(filename)

        args = {
            'url': path,
            'baseType': baseType,
            'originalfile': originalfile,
            'filename': time + filename
        }

        response = requests.post(results_url, args)
        return response

# %% [markdown]
# ***READING DATAFRAME***

# %%
############## CREATE SPARK SESSION ############################ ENTER YOUR SPARK MASTER IP AND PORT TO CONNECT TO SERVER ################
from pyspark.sql import SparkSession
spark = SparkSession.builder.master('local[1]').getOrCreate()
#%run dataprepdateconvHooks.ipynb
try:
	#sourcePreExecutionHook()

	trainxugy = HDFSConnector.fetch(spark, "{'url': '/FileStore/platform/testdata/1717136487987_Train.csv', 'filename': 'Train.csv', 'delimiter': ',', 'file_type': 'Delimeted', 'dbfs_token': '', 'dbfs_domain': '', 'FilePath': '/healthcare/CoronaHospitalCapability/datafiles/Train.csv', 'viewFileName': 'Train.csv', 'is_header': 'Use Header Line', 'baseType': 'hdfs', 'server_url': '/nexusMax/NexusMaxPlatform/uploads/platform/', 'results_url': 'http://dnm.bfirst.ai:44040/api/read/hdfs'}")

except Exception as ex: 
	logging.error(ex)
#spark.stop()

# %% [markdown]
# ***PERFORMING OPERATIONS***

# %%
#%run dataprepdateconvHooks.ipynb
try:
	#operationPreExecutionHook()

datapreparation = runDataCleansing(trainxugy,spark,json.dumps( {"url": "/FileStore/platform/testdata/1717136487987_Train.csv", "source_attributes": {}, "DataPrepFile": "/FileStore/platform/testdata/1717136487987_Train.csv", "data_source": "platfiles", "startListenerOnly": 1, "dateColumnNames": ["collection_week"], "FilePath": "/FileStore/platform/extra/665d6a7b595b0a3927b538681717398405/0part.csv", "requestRatio": 1.0, "totalRows": 742, "BasicStats": {"missingValues": 0.0, "numberOfColumns": 25, "numberOfRows": 742, "duplicateRowCount": 0, "stats": [{"column": "_c0", "alias": "_c0", "generated": 0, "type": "numeric", "max": 741756, "min": 193, "mean": 374776.3962264151, "missing": 0.0, "stddev": 214964.83, "outliers": [], "validation": []}, {"column": "hospital_pk", "alias": "hospital_pk", "generated": 0, "type": "String", "max": "b2937a1082df4731d7489c512c9155927bb390a498502997939ac4dd8308ffc0", "min": "100023", "mean": "", "missing": 0.0, "stddev": "", "outliers": [], "validation": []}, {"column":
"all_adult_hospital_inpatient_beds_7_day_sum": 0.0211610347, "all_pediatric_inpatient_bed_occupied_7_day_avg": 3.423e-05, "city": 1.0, "collection_week": 0.0004421357, "fips_code": 0.2235354774, "hospital_pk": 0.1356678966, "hospital_subtype": 0.0001204342, "icu_beds_used_7_day_sum": 0.0018711624, "inpatient_beds_7_day_sum": 0.0191830054, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0, "is_metro_micro": 6.454e-07, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0025678662, "previous_day_covid_ED_visits_7_day_sum": 0.0035871901, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0003728945, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 0.0485440062, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0001211382, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0021371488, "total_beds_7_day_avg": 0.0176012215, "total_beds_7_day_sum": 0.0185011185, "total_icu_beds_7_day_sum": 0.0107651533, "total_staffed_adult_icu_beds_7_day_sum": 0.0145026806}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.0, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 1.0, "fips_code": 0.0, "hospital_pk": 0.0, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0, "inpatient_beds_7_day_sum": 0.0, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0, "total_beds_7_day_avg": 0.0, "total_beds_7_day_sum": 0.0, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0}, {"_c0": 0.970434919, "all_adult_hospital_beds_7_day_sum": 0.0, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.1587323514, "collection_week": 0.0, "fips_code": 1.0, "hospital_pk": 0.0, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0, "inpatient_beds_7_day_sum": 0.0, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 0.9708616277, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0, "total_beds_7_day_avg": 0.0, "total_beds_7_day_sum": 0.0, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.0, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 1.0, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0, "inpatient_beds_7_day_sum": 0.0, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0, "total_beds_7_day_avg": 0.0, "total_beds_7_day_sum": 0.0, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0}, {"_c0": 0.7650021858, "all_adult_hospital_beds_7_day_sum": 0.3762069513, "all_adult_hospital_inpatient_beds_7_day_sum": 0.4622736772, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.1384030643, "collection_week": 0.0, "fips_code": 0.2225726964, "hospital_pk": 0.1342264101, "hospital_subtype": 1.0, "icu_beds_used_7_day_sum": 0.3139802939, "inpatient_beds_7_day_sum": 0.4729793369, "inpatient_beds_used_covid_7_day_avg": 0.0111253307, "inpatient_beds_used_covid_7_day_sum": 0.2589964517, "is_metro_micro": 0.4338623029, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.1014655149, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 0.2833041309, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0840334062, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0064415254, "total_beds_7_day_avg": 0.4418873678, "total_beds_7_day_sum": 0.4367036388, "total_icu_beds_7_day_sum": 0.4253963015, "total_staffed_adult_icu_beds_7_day_sum": 0.36542041}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.249972615, "all_adult_hospital_inpatient_beds_7_day_sum": 0.3902500499, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0658881385, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 1.0, "inpatient_beds_7_day_sum": 0.3905544163, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0095020691, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0, "total_beds_7_day_avg": 0.1986550509, "total_beds_7_day_sum": 0.2320790202, "total_icu_beds_7_day_sum": 0.6073073898, "total_staffed_adult_icu_beds_7_day_sum": 0.5878375469}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.4817697732, "all_adult_hospital_inpatient_beds_7_day_sum": 0.7249233277, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0008579007, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0578524942, "hospital_subtype": 0.0484736168, "icu_beds_used_7_day_sum": 0.3969162396, "inpatient_beds_7_day_sum": 1.0, "inpatient_beds_used_covid_7_day_avg": 0.0044087872, "inpatient_beds_used_covid_7_day_sum": 0.0615936825, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.052582862, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0149813798, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0363637653, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.051873591, "total_beds_7_day_avg": 0.5786820001, "total_beds_7_day_sum": 0.6598721873, "total_icu_beds_7_day_sum": 0.4781992046, "total_staffed_adult_icu_beds_7_day_sum": 0.4291457324}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.0, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0066140495, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0, "inpatient_beds_7_day_sum": 0.0, "inpatient_beds_used_covid_7_day_avg": 1.0, "inpatient_beds_used_covid_7_day_sum": 0.881978801, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.1827762044, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.2041421838, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.6979197606, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.5722709401, "total_beds_7_day_avg": 0.0, "total_beds_7_day_sum": 0.0, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.0, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0, "inpatient_beds_7_day_sum": 0.0, "inpatient_beds_used_covid_7_day_avg": 0.8360902802, "inpatient_beds_used_covid_7_day_sum": 1.0, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.2231358388, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.252740459, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.746573785, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.6228330179, "total_beds_7_day_avg": 0.0, "total_beds_7_day_sum": 0.0, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0}, {"_c0": 0.0342580207, "all_adult_hospital_beds_7_day_sum": 0.0, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.027199421, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.068301764, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0, "inpatient_beds_7_day_sum": 0.0, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0, "is_metro_micro": 1.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0, "total_beds_7_day_avg": 0.0, "total_beds_7_day_sum": 0.0, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.0, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0204046006, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0, "inpatient_beds_7_day_sum": 0.0, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 1.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0, "total_beds_7_day_avg": 0.0, "total_beds_7_day_sum": 0.0, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.0, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0, "inpatient_beds_7_day_sum": 0.0, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 1.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0, "total_beds_7_day_avg": 0.0, "total_beds_7_day_sum": 0.0, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.0, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0, "inpatient_beds_7_day_sum": 0.0, "inpatient_beds_used_covid_7_day_avg": 0.1662302684, "inpatient_beds_used_covid_7_day_sum": 0.2096372149, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 1.0, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.825355003, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.3238100267, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.371242436, "total_beds_7_day_avg": 0.0, "total_beds_7_day_sum": 0.0, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0346629115}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.0, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0, "inpatient_beds_7_day_sum": 0.0, "inpatient_beds_used_covid_7_day_avg": 0.1327228301, "inpatient_beds_used_covid_7_day_sum": 0.1818427655, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.8225786998, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 1.0, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.2963301382, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.3859084789, "total_beds_7_day_avg": 0.0, "total_beds_7_day_sum": 0.0, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0214729759}, {"_c0": 0.9544085849, "all_adult_hospital_beds_7_day_sum": 0.0165898074, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0324756514, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.2625270186, "collection_week": 0.0094025986, "fips_code": 0.9952515339, "hospital_pk": 0.1433807817, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0127895079, "inpatient_beds_7_day_sum": 0.0214040719, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 1.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0, "total_beds_7_day_avg": 0.0141145476, "total_beds_7_day_sum": 0.0226282612, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0061461436}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.0, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0, "inpatient_beds_7_day_sum": 0.0, "inpatient_beds_used_covid_7_day_avg": 0.6271192033, "inpatient_beds_used_covid_7_day_sum": 0.7144569687, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.3146840405, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.3368797573, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 1.0, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.7828656426, "total_beds_7_day_avg": 0.0, "total_beds_7_day_sum": 0.0, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0396946647}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.0, "all_adult_hospital_inpatient_beds_7_day_sum": 0.0, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.0, "inpatient_beds_7_day_sum": 0.0, "inpatient_beds_used_covid_7_day_avg": 0.526130315, "inpatient_beds_used_covid_7_day_sum": 0.6131700818, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.3218760463, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.3594247149, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.793438308, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 1.0, "total_beds_7_day_avg": 0.0, "total_beds_7_day_sum": 0.0, "total_icu_beds_7_day_sum": 0.0, "total_staffed_adult_icu_beds_7_day_sum": 0.0270173817}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.6069753197, "all_adult_hospital_inpatient_beds_7_day_sum": 0.3673739396, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0, "hospital_subtype": 0.0108967157, "icu_beds_used_7_day_sum": 0.2013106632, "inpatient_beds_7_day_sum": 0.4957879458, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0121521783, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0, "total_beds_7_day_avg": 1.0, "total_beds_7_day_sum": 0.9095592663, "total_icu_beds_7_day_sum": 0.3213592611, "total_staffed_adult_icu_beds_7_day_sum": 0.287390704}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.6392329707, "all_adult_hospital_inpatient_beds_7_day_sum": 0.3832541099, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.2008923018, "inpatient_beds_7_day_sum": 0.5670692405, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0039701997, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0, "total_beds_7_day_avg": 0.8699920592, "total_beds_7_day_sum": 1.0, "total_icu_beds_7_day_sum": 0.3135783255, "total_staffed_adult_icu_beds_7_day_sum": 0.2884089493}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.2434599951, "all_adult_hospital_inpatient_beds_7_day_sum": 0.3241893097, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0571717181, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.5682066226, "inpatient_beds_7_day_sum": 0.4469849108, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0, "total_beds_7_day_avg": 0.2844830619, "total_beds_7_day_sum": 0.307172648, "total_icu_beds_7_day_sum": 1.0, "total_staffed_adult_icu_beds_7_day_sum": 0.5011643438}, {"_c0": 0.0, "all_adult_hospital_beds_7_day_sum": 0.4045706383, "all_adult_hospital_inpatient_beds_7_day_sum": 0.537302064, "all_pediatric_inpatient_bed_occupied_7_day_avg": 0.0, "city": 0.0, "collection_week": 0.0, "fips_code": 0.0, "hospital_pk": 0.0518654514, "hospital_subtype": 0.0, "icu_beds_used_7_day_sum": 0.5814038288, "inpatient_beds_7_day_sum": 0.3404944467, "inpatient_beds_used_covid_7_day_avg": 0.0, "inpatient_beds_used_covid_7_day_sum": 0.0, "is_metro_micro": 0.0, "previous_day_admission_adult_covid_suspected_7_day_sum": 0.0, "previous_day_covid_ED_visits_7_day_sum": 0.0, "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum": 0.0803745714, "staffed_icu_adult_patients_confirmed_covid_7_day_sum": 0.0565829396, "state": 0.0, "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum": 0.0398127912, "total_adult_patients_hospitalized_confirmed_covid_7_day_sum": 0.0613729876, "total_beds_7_day_avg": 0.272797017, "total_beds_7_day_sum": 0.3032748181, "total_icu_beds_7_day_sum": 0.5379463988, "total_staffed_adult_icu_beds_7_day_sum": 1.0}], "HasBasicStats": 1, "functionsApplied": [{"functionName": "transformDate", "applyOn": [{"columnName": "collection_week", "type": "date", "min": "2020320", "max": "2023210", "mean": "-"}], "functionsData": [{"column": [{"columnName": "collection_week", "type": "date", "min": "2020320", "max": "2023210", "mean": "-"}], "inputDateFormat": "MM/DD/YYYY", "outputDateFormat": "YYYY-MM-DD", "newColumn": "False"}]}, {"functionName": "sortData", "applyOn": [{"columnName": "collection_week", "type": "date", "min": "2020320", "max": "2023210", "mean": "-"}], "functionsData": [{"column": [{"columnName": "collection_week", "type": "date", "min": "2020320", "max": "2023210", "mean": "-"}], "order": "asc"}]}], "functionChanges": [{"columnName": "collection_week", "functionName": "transformDate", "Type": "date", "Parameters": [{"column": [{"columnName": "collection_week", "type": "date", "min": "2020320", "max": "2023210", "mean": "-"}], "inputDateFormat": "MM/DD/YYYY", "outputDateFormat": "YYYY-MM-DD", "newColumn": "False"}]}, {"columnName": "collection_week", "functionName": "sortData", "Type": "date", "Parameters": [{"column": [{"columnName": "collection_week", "type": "date", "min": "2020320", "max": "2023210", "mean": "-"}], "order": "asc"}]}], "fileheader": [{"field": "_c0", "alias": "_c0", "generated": 0, "position": 1, "type": "numeric"}, {"field": "hospital_pk", "alias": "hospital_pk", "generated": 0, "position": 2, "type": "String"}, {"field": "collection_week", "alias": "collection_week", "generated": 0, "position": 3, "type": "date"}, {"field": "state", "alias": "state", "generated": 0, "position": 4, "type": "String"}, {"field": "city", "alias": "city", "generated": 0, "position": 5, "type": "String"}, {"field": "hospital_subtype", "alias": "hospital_subtype", "generated": 0, "position": 6, "type": "String"}, {"field": "fips_code", "alias": "fips_code", "generated": 0, "position": 7, "type": "numeric"}, {"field": "is_metro_micro", "alias": "is_metro_micro", "generated": 0, "position": 8, "type": "numeric"}, {"field": "total_beds_7_day_avg", "alias": "total_beds_7_day_avg", "generated": 0, "position": 9, "type": "real"}, {"field": "inpatient_beds_used_covid_7_day_avg", "alias": "inpatient_beds_used_covid_7_day_avg", "generated": 0, "position": 10, "type": "real"}, {"field": "total_beds_7_day_sum", "alias": "total_beds_7_day_sum", "generated": 0, "position": 11, "type": "numeric"}, {"field": "all_adult_hospital_beds_7_day_sum", "alias": "all_adult_hospital_beds_7_day_sum", "generated": 0, "position": 12, "type": "numeric"}, {"field": "all_adult_hospital_inpatient_beds_7_day_sum", "alias": "all_adult_hospital_inpatient_beds_7_day_sum", "generated": 0, "position": 13, "type": "numeric"}, {"field": "inpatient_beds_used_covid_7_day_sum", "alias": "inpatient_beds_used_covid_7_day_sum", "generated": 0, "position": 14, "type": "numeric"}, {"field": "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum", "alias": "total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum", "generated": 0, "position": 15, "type": "numeric"}, {"field": "total_adult_patients_hospitalized_confirmed_covid_7_day_sum", "alias": "total_adult_patients_hospitalized_confirmed_covid_7_day_sum", "generated": 0, "position": 16, "type": "numeric"}, {"field": "inpatient_beds_7_day_sum", "alias": "inpatient_beds_7_day_sum", "generated": 0, "position": 17, "type": "numeric"}, {"field": "total_icu_beds_7_day_sum", "alias": "total_icu_beds_7_day_sum", "generated": 0, "position": 18, "type": "numeric"}, {"field": "total_staffed_adult_icu_beds_7_day_sum", "alias": "total_staffed_adult_icu_beds_7_day_sum", "generated": 0, "position": 19, "type": "numeric"}, {"field": "icu_beds_used_7_day_sum", "alias": "icu_beds_used_7_day_sum", "generated": 0, "position": 20, "type": "numeric"}, {"field": "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum", "alias": "staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum", "generated": 0, "position": 21, "type": "numeric"}, {"field": "staffed_icu_adult_patients_confirmed_covid_7_day_sum", "alias": "staffed_icu_adult_patients_confirmed_covid_7_day_sum", "generated": 0, "position": 22, "type": "numeric"}, {"field": "previous_day_covid_ED_visits_7_day_sum", "alias": "previous_day_covid_ED_visits_7_day_sum", "generated": 0, "position": 23, "type": "numeric"}, {"field": "previous_day_admission_adult_covid_suspected_7_day_sum", "alias": "previous_day_admission_adult_covid_suspected_7_day_sum", "generated": 0, "position": 24, "type": "numeric"}, {"field": "all_pediatric_inpatient_bed_occupied_7_day_avg", "alias": "all_pediatric_inpatient_bed_occupied_7_day_avg", "generated": 0, "position": 25, "type": "real"}]}))
	#operationPostExecutionHook(datapreparation)

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***WRITING DATAFRAME***

# %%
#%run dataprepdateconvHooks.ipynb
try:
	#sinkPreExecutionHook()

	datapipefortsoutput = NumtraConnector.fetch(spark, "{'samplefile': '/FileStore/platform/sampleData/665d6a74595b0a3927b53864/part-00000-9a680e12-0679-443d-961a-55a16113df98-c000.csv', 'samplecount': 742, 'originalcount': 742, 'orignalKey': '/FileStore/platform/testdata/1717136487987_Train.csv', 'pathOnly': '/healthcare/CoronaHospitalCapability/datapipeforTS', 'project_id': '665993e56e3600cfb7189b4f', 'parent_id': '665993e56e3600cfb7189b4f', 'original_schema': [{'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': '_c0', 'alias': '_c0', 'type': 'numeric', 'position': '0'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'hospital_pk', 'alias': 'hospital_pk', 'type': 'String', 'position': '1'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'collection_week', 'alias': 'collection_week', 'type': 'date', 'position': '2'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'state', 'alias': 'state', 'type': 'String', 'position': '3'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'city', 'alias': 'city', 'type': 'String', 'position': '4'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'hospital_subtype', 'alias': 'hospital_subtype', 'type': 'String', 'position': '5'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'fips_code', 'alias': 'fips_code', 'type': 'numeric', 'position': '6'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'is_metro_micro', 'alias': 'is_metro_micro', 'type': 'numeric', 'position': '7'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'total_beds_7_day_avg', 'alias': 'total_beds_7_day_avg', 'type': 'real', 'position': '8'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'inpatient_beds_used_covid_7_day_avg', 'alias': 'inpatient_beds_used_covid_7_day_avg', 'type': 'real', 'position': '9'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'total_beds_7_day_sum', 'alias': 'total_beds_7_day_sum', 'type': 'numeric', 'position': '10'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'all_adult_hospital_beds_7_day_sum', 'alias': 'all_adult_hospital_beds_7_day_sum', 'type': 'numeric', 'position': '11'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'all_adult_hospital_inpatient_beds_7_day_sum', 'alias': 'all_adult_hospital_inpatient_beds_7_day_sum', 'type': 'numeric', 'position': '12'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'inpatient_beds_used_covid_7_day_sum', 'alias': 'inpatient_beds_used_covid_7_day_sum', 'type': 'numeric', 'position': '13'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum', 'alias': 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum', 'type': 'numeric', 'position': '14'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum', 'alias': 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum', 'type': 'numeric', 'position': '15'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'inpatient_beds_7_day_sum', 'alias': 'inpatient_beds_7_day_sum', 'type': 'numeric', 'position': '16'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'total_icu_beds_7_day_sum', 'alias': 'total_icu_beds_7_day_sum', 'type': 'numeric', 'position': '17'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'total_staffed_adult_icu_beds_7_day_sum', 'alias': 'total_staffed_adult_icu_beds_7_day_sum', 'type': 'numeric', 'position': '18'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'icu_beds_used_7_day_sum', 'alias': 'icu_beds_used_7_day_sum', 'type': 'numeric', 'position': '19'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum', 'alias': 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum', 'type': 'numeric', 'position': '20'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'staffed_icu_adult_patients_confirmed_covid_7_day_sum', 'alias': 'staffed_icu_adult_patients_confirmed_covid_7_day_sum', 'type': 'numeric', 'position': '21'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'previous_day_covid_ED_visits_7_day_sum', 'alias': 'previous_day_covid_ED_visits_7_day_sum', 'type': 'numeric', 'position': '22'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'previous_day_admission_adult_covid_suspected_7_day_sum', 'alias': 'previous_day_admission_adult_covid_suspected_7_day_sum', 'type': 'numeric', 'position': '23'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'all_pediatric_inpatient_bed_occupied_7_day_avg', 'alias': 'all_pediatric_inpatient_bed_occupied_7_day_avg', 'type': 'real', 'position': '24'}], 'actual_schema': [{'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': '_c0', 'alias': '_c0', 'type': 'numeric', 'position': '0'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'hospital_pk', 'alias': 'hospital_pk', 'type': 'String', 'position': '1'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'collection_week', 'alias': 'collection_week', 'type': 'date', 'position': '2'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'state', 'alias': 'state', 'type': 'String', 'position': '3'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'city', 'alias': 'city', 'type': 'String', 'position': '4'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'hospital_subtype', 'alias': 'hospital_subtype', 'type': 'String', 'position': '5'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'fips_code', 'alias': 'fips_code', 'type': 'numeric', 'position': '6'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'is_metro_micro', 'alias': 'is_metro_micro', 'type': 'numeric', 'position': '7'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'total_beds_7_day_avg', 'alias': 'total_beds_7_day_avg', 'type': 'real', 'position': '8'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'inpatient_beds_used_covid_7_day_avg', 'alias': 'inpatient_beds_used_covid_7_day_avg', 'type': 'real', 'position': '9'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'total_beds_7_day_sum', 'alias': 'total_beds_7_day_sum', 'type': 'numeric', 'position': '10'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'all_adult_hospital_beds_7_day_sum', 'alias': 'all_adult_hospital_beds_7_day_sum', 'type': 'numeric', 'position': '11'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'all_adult_hospital_inpatient_beds_7_day_sum', 'alias': 'all_adult_hospital_inpatient_beds_7_day_sum', 'type': 'numeric', 'position': '12'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'inpatient_beds_used_covid_7_day_sum', 'alias': 'inpatient_beds_used_covid_7_day_sum', 'type': 'numeric', 'position': '13'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum', 'alias': 'total_adult_patients_hospitalized_confirmed_and_suspected_covid_7_day_sum', 'type': 'numeric', 'position': '14'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum', 'alias': 'total_adult_patients_hospitalized_confirmed_covid_7_day_sum', 'type': 'numeric', 'position': '15'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'inpatient_beds_7_day_sum', 'alias': 'inpatient_beds_7_day_sum', 'type': 'numeric', 'position': '16'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'total_icu_beds_7_day_sum', 'alias': 'total_icu_beds_7_day_sum', 'type': 'numeric', 'position': '17'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'total_staffed_adult_icu_beds_7_day_sum', 'alias': 'total_staffed_adult_icu_beds_7_day_sum', 'type': 'numeric', 'position': '18'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'icu_beds_used_7_day_sum', 'alias': 'icu_beds_used_7_day_sum', 'type': 'numeric', 'position': '19'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum', 'alias': 'staffed_icu_adult_patients_confirmed_and_suspected_covid_7_day_sum', 'type': 'numeric', 'position': '20'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'staffed_icu_adult_patients_confirmed_covid_7_day_sum', 'alias': 'staffed_icu_adult_patients_confirmed_covid_7_day_sum', 'type': 'numeric', 'position': '21'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'previous_day_covid_ED_visits_7_day_sum', 'alias': 'previous_day_covid_ED_visits_7_day_sum', 'type': 'numeric', 'position': '22'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'previous_day_admission_adult_covid_suspected_7_day_sum', 'alias': 'previous_day_admission_adult_covid_suspected_7_day_sum', 'type': 'numeric', 'position': '23'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', 'field': 'all_pediatric_inpatient_bed_occupied_7_day_avg', 'alias': 'all_pediatric_inpatient_bed_occupied_7_day_avg', 'type': 'real', 'position': '24'}], 'server': 'https://dnm.bfirst.ai:443', 'server_url': '/nexusMax/NexusMaxPlatform/uploads/platform/', 'delimiter': ',', 'file_type': 'Delimeted', 'filename': 'secondoutput.csv', 'token': '', 'domain': '', 'is_header': 'Use Header Line', 'url': '/FileStore/platform/uploadedSourceFiles/part-00000-a9b3d31d-0dfa-4677-b195-fae293fd82be-c000.csv', 'results_url': 'http://dnm.bfirst.ai:44040/api/read/hdfs'}")

except Exception as ex: 
	logging.error(ex)
